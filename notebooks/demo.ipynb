# %% [markdown]
# # ConfluxDuck demo
# This notebook demonstrates loading CSVs into unified.duckdb and running simple queries.

# %%
import duckdb
con = duckdb.connect('unified.duckdb')
print(con.execute('SELECT 1').fetchall())
